# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mutual_info_score
from sklearn.metrics import accuracy_score 
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('E:\Leads.csv')
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# 0                            0                   0.0  ...
# 1                          674                   2.5  ...
# 2                         1532                   2.0  ...
# 3                          305                   1.0  ...
# 4                         1428                   1.0  ...
#
#   Get updates on DM Content    Lead Profile    City  \
# 0                        No          Select  Select
# 1                        No          Select  Select
# 2                        No  Potential Lead  Mumbai
# 3                        No          Select  Mumbai
# 4                        No          Select  Mumbai
#
#   Asymmetrique Activity Index Asymmetrique Profile Index  \
# 0                   02.Medium                  02.Medium
# 1                   02.Medium                  02.Medium
# 2                   02.Medium                    01.High
# 3                   02.Medium                    01.High
# 4                   02.Medium                    01.High
#
#   Asymmetrique Activity Score Asymmetrique Profile Score  \
# 0                        15.0                       15.0
# 1                        15.0                       15.0
# 2                        14.0                       20.0
# 3                        13.0                       17.0
# 4                        15.0                       18.0
#
#   I agree to pay the amount through cheque  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   A free copy of Mastering The Interview Last Notable Activity
# 0                                     No              Modified
# 1                                     No          Email Opened
# 2                                    Yes          Email Opened
# 3                                     No              Modified
# 4                                     No              Modified
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (9240, 37)

# %%
df.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# min                0.000000                     7.000000
# 25%                1.000000                    14.000000
# 50%                2.000000                    14.000000
# 75%                3.000000                    15.000000
# max               55.000000                    18.000000
#
#        Asymmetrique Profile Score
# count                 5022.000000
# mean                    16.344883
# std                      1.811395
# min                     11.000000
# 25%                     15.000000
# 50%                     16.000000
# 75%                     18.000000
# max                     20.000000

# %% [markdown]
# ### Initial data preparation

# %%
#lowerCase the columns names 
df.columns = df.columns.str.lower().str.replace(' ','_')

#select columns with string values 
string_columns= list(df.dtypes[df.dtypes==object].index)

#Lowercases and replaces spaces with underscoresfor values in all string columns of the DataFrame 
for col in string_columns:
    df[col]=df[col].str.lower().str.replace(' ','_')

# %% [markdown]
# * Cheking for missing values

# %%
df.isnull().sum()
# Out:
# prospect_id                                         0
# lead_number                                         0
# lead_origin                                         0
# lead_source                                        36
# do_not_email                                        0
# do_not_call                                         0
# converted                                           0
# totalvisits                                       137
# total_time_spent_on_website                         0
# page_views_per_visit                              137
# last_activity                                     103
# country                                          2461
# specialization                                   1438
# how_did_you_hear_about_x_education               2207
# what_is_your_current_occupation                  2690
# what_matters_most_to_you_in_choosing_a_course    2709
# search                                              0
# magazine                                            0
# newspaper_article                                   0
# x_education_forums                                  0
# newspaper                                           0
# digital_advertisement                               0
# through_recommendations                             0
# receive_more_updates_about_our_courses              0
# tags                                             3353
# lead_quality                                     4767
# update_me_on_supply_chain_content                   0
# get_updates_on_dm_content                           0
# lead_profile                                     2709
# city                                             1420
# asymmetrique_activity_index                      4218
# asymmetrique_profile_index                       4218
# asymmetrique_activity_score                      4218
# asymmetrique_profile_score                       4218
# i_agree_to_pay_the_amount_through_cheque            0
# a_free_copy_of_mastering_the_interview              0
# last_notable_activity                               0
# dtype: int64

# %% [markdown]
# ### Handeling missing Values
# #### mode for categorical variables
# #### mean for numerical variables

# %%
categorical=['lead_origin','lead_source','do_not_email','do_not_call'
             ,'last_activity','country','specialization', 'how_did_you_hear_about_x_education',
             'what_is_your_current_occupation','what_matters_most_to_you_in_choosing_a_course','search',
            'magazine','newspaper_article','digital_advertisement', 'through_recommendations','receive_more_updates_about_our_courses',
            'tags', 'lead_quality','update_me_on_supply_chain_content','lead_profile','city',
            'asymmetrique_activity_index','asymmetrique_profile_index', 'i_agree_to_pay_the_amount_through_cheque',
            'a_free_copy_of_mastering_the_interview','last_notable_activity']
numerical=['totalvisits','total_time_spent_on_website','page_views_per_visit','asymmetrique_activity_score','asymmetrique_profile_score']

# %%
for cat in categorical:
    df[cat]= df[cat].fillna(df[cat].mode()[0])
for num in numerical :
    df[num]= df[num].fillna(df[num].mean())

# %%
def calculate_mi(series):
    return mutual_info_score(series,df.converted)

# %%
df_mi = df[categorical].apply(calculate_mi)
df_mi = df_mi.sort_values(ascending=False).to_frame(name="MI")
df_mi
# Out:
#                                                      MI
# tags                                           0.206630
# lead_quality                                   0.107821
# last_activity                                  0.084493
# lead_profile                                   0.082869
# last_notable_activity                          0.073860
# lead_source                                    0.061560
# lead_origin                                    0.056251
# what_is_your_current_occupation                0.053389
# specialization                                 0.014624
# city                                           0.012024
# asymmetrique_activity_index                    0.011140
# do_not_email                                   0.010327
# asymmetrique_profile_index                     0.005266
# country                                        0.002900
# how_did_you_hear_about_x_education             0.001446
# a_free_copy_of_mastering_the_interview         0.000797
# do_not_call                                    0.000206
# through_recommendations                        0.000168
# what_matters_most_to_you_in_choosing_a_course  0.000059
# digital_advertisement                          0.000018
# newspaper_article                              0.000006
# search                                         0.000003
# receive_more_updates_about_our_courses         0.000000
# update_me_on_supply_chain_content              0.000000
# magazine                                       0.000000
# i_agree_to_pay_the_amount_through_cheque       0.000000

# %% [markdown]
# * We drop these features which are the least important

# %%
df.drop(['do_not_call',
'through_recommendations',
'what_matters_most_to_you_in_choosing_a_course',
'digital_advertisement',
'newspaper_article',
'search',
'receive_more_updates_about_our_courses',
'update_me_on_supply_chain_content',
'magazine',
'i_agree_to_pay_the_amount_through_cheque'],axis=1,inplace=True

)

# %%
df.shape[1]
# Out:
# 27

# %% [markdown]
# ### Correlation Coefficient( linear relationship between variables and the target variables)

# %%
df[numerical].corrwith(df.converted)
# Out:
# totalvisits                    0.030091
# total_time_spent_on_website    0.362483
# page_views_per_visit          -0.003294
# asymmetrique_activity_score    0.123491
# asymmetrique_profile_score     0.160700
# dtype: float64

# %%
new_categorical =['lead_origin','lead_source','do_not_email'
             ,'last_activity','country','specialization', 'how_did_you_hear_about_x_education',
             'what_is_your_current_occupation',
            'tags', 'lead_quality','lead_profile','city',
            'asymmetrique_activity_index','asymmetrique_profile_index',
            'a_free_copy_of_mastering_the_interview','last_notable_activity']

# %%
df_train_full, df_test= train_test_split(df,test_size=0.2,random_state=1)

df_train, df_val= train_test_split(df_train_full,test_size=0.33, random_state=11)

y_train = df_train.converted.values
y_val = df_val.converted.values
y_test = df_test.converted.values

# %%
del df_train['converted']
del df_val['converted']
del df_test['converted']

# %% [markdown]
# ### FEATURE ENGINEERING

# %% [markdown]
# * One Hot Encoding

# %%
train_dic = df_train[new_categorical+ numerical].to_dict(orient='records')
train_dic
# Out:
# [{'lead_origin': 'lead_add_form',
#   'lead_source': 'reference',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'media_and_advertising',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'want_to_take_admission_but_has_financial_problems',
#   'lead_quality': 'low_in_relevance',
#   'lead_profile': 'potential_lead',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'yes',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'it_projects_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'switched_off',
#   'lead_quality': 'not_sure',
#   'lead_profile': 'select',
#   'city': 'other_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 1103,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'organic_search',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'banking,_investment_and_insurance',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'thane_&_outskirts',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'modified',
#   'totalvisits': 5.0,
#   'total_time_spent_on_website': 1326,
#   'page_views_per_visit': 5.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 17.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'human_resource_management',
#   'how_did_you_hear_about_x_education': 'other',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'other_cities_of_maharashtra',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 31,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'retail_management',
#   'how_did_you_hear_about_x_education': 'other',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'graduation_in_progress',
#   'lead_quality': 'high_in_relevance',
#   'lead_profile': 'potential_lead',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 6.0,
#   'total_time_spent_on_website': 1048,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 15.0,
#   'asymmetrique_profile_score': 20.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'human_resource_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'other_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 1017,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_link_clicked',
#   'country': 'india',
#   'specialization': 'human_resource_management',
#   'how_did_you_hear_about_x_education': 'online_search',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'other_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_link_clicked',
#   'totalvisits': 4.0,
#   'total_time_spent_on_website': 750,
#   'page_views_per_visit': 4.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 17.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'other',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'ringing',
#   'lead_quality': 'not_sure',
#   'lead_profile': 'other_leads',
#   'city': 'other_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 6.0,
#   'total_time_spent_on_website': 71,
#   'page_views_per_visit': 6.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 16.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'international_business',
#   'how_did_you_hear_about_x_education': 'word_of_mouth',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 248,
#   'page_views_per_visit': 1.5,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'yes',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'switched_off',
#   'lead_quality': 'might_be',
#   'lead_profile': 'potential_lead',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '03.low',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 40,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 10.0,
#   'asymmetrique_profile_score': 20.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 16.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'human_resource_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'high_in_relevance',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 16.0,
#   'asymmetrique_profile_score': 16.0},
#  {'lead_origin': 'lead_import',
#   'lead_source': 'facebook',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 3.445237833681204,
#   'total_time_spent_on_website': 1608,
#   'page_views_per_visit': 2.3628199494672084,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'multiple_sources',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 251,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'organic_search',
#   'do_not_email': 'yes',
#   'last_activity': 'page_visited_on_website',
#   'country': 'bahrain',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'thane_&_outskirts',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'modified',
#   'totalvisits': 7.0,
#   'total_time_spent_on_website': 204,
#   'page_views_per_visit': 3.5,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'referral_sites',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'select',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 11.0,
#   'total_time_spent_on_website': 1863,
#   'page_views_per_visit': 5.5,
#   'asymmetrique_activity_score': 16.0,
#   'asymmetrique_profile_score': 13.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'ringing',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'e-commerce',
#   'how_did_you_hear_about_x_education': 'word_of_mouth',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'ringing',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 4.0,
#   'total_time_spent_on_website': 1579,
#   'page_views_per_visit': 4.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 4.0,
#   'total_time_spent_on_website': 230,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 253,
#   'page_views_per_visit': 1.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'business_administration',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'working_professional',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 11.0,
#   'total_time_spent_on_website': 2069,
#   'page_views_per_visit': 5.5,
#   'asymmetrique_activity_score': 16.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'form_submitted_on_website',
#   'country': 'india',
#   'specialization': 'operations_management',
#   'how_did_you_hear_about_x_education': 'word_of_mouth',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'ringing',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '03.low',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 1058,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 12.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'retail_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'ringing',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 316,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 13.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'word_of_mouth',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'wrong_number_given',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 336,
#   'page_views_per_visit': 1.5,
#   'asymmetrique_activity_score': 13.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'lead_add_form',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 16.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'olark_chat_conversation',
#   'totalvisits': 1.0,
#   'total_time_spent_on_website': 329,
#   'page_views_per_visit': 1.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'organic_search',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'healthcare_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'high_in_relevance',
#   'lead_profile': 'potential_lead',
#   'city': 'other_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 7.0,
#   'total_time_spent_on_website': 467,
#   'page_views_per_visit': 7.0,
#   'asymmetrique_activity_score': 15.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'operations_management',
#   'how_did_you_hear_about_x_education': 'online_search',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 8.0,
#   'total_time_spent_on_website': 100,
#   'page_views_per_visit': 2.67,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'hospitality_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '03.low',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 331,
#   'page_views_per_visit': 1.5,
#   'asymmetrique_activity_score': 12.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'human_resource_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'closed_by_horizzon',
#   'lead_quality': 'low_in_relevance',
#   'lead_profile': 'select',
#   'city': 'other_metro_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'modified',
#   'totalvisits': 6.0,
#   'total_time_spent_on_website': 954,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'potential_lead',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 970,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 15.0,
#   'asymmetrique_profile_score': 16.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'organic_search',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'operations_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'not_sure',
#   'lead_profile': 'select',
#   'city': 'other_metro_cities',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 13.0,
#   'total_time_spent_on_website': 86,
#   'page_views_per_visit': 6.5,
#   'asymmetrique_activity_score': 16.0,
#   'asymmetrique_profile_score': 16.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'kuwait',
#   'specialization': 'retail_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'already_a_student',
#   'lead_quality': 'worst',
#   'lead_profile': 'student_of_someschool',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 1502,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 16.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'lead_add_form',
#   'lead_source': 'reference',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'business_administration',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'lost_to_eins',
#   'lead_quality': 'high_in_relevance',
#   'lead_profile': 'potential_lead',
#   'city': 'other_cities_of_maharashtra',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 15.0,
#   'asymmetrique_profile_score': 19.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'email_link_clicked',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'other_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'email_link_clicked',
#   'totalvisits': 5.0,
#   'total_time_spent_on_website': 290,
#   'page_views_per_visit': 1.67,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'multiple_sources',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'thane_&_outskirts',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'olark_chat_conversation',
#   'totalvisits': 11.0,
#   'total_time_spent_on_website': 1858,
#   'page_views_per_visit': 2.2,
#   'asymmetrique_activity_score': 17.0,
#   'asymmetrique_profile_score': 17.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'lead_add_form',
#   'lead_source': 'reference',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'high_in_relevance',
#   'lead_profile': 'potential_lead',
#   'city': 'thane_&_outskirts',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'organic_search',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'interested_in_other_courses',
#   'lead_quality': 'not_sure',
#   'lead_profile': 'select',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 623,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'yes',
#   'last_activity': 'page_visited_on_website',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'number_not_provided',
#   'lead_quality': 'worst',
#   'lead_profile': 'select',
#   'city': 'other_cities_of_maharashtra',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 4.0,
#   'total_time_spent_on_website': 281,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'united_arab_emirates',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'working_professional',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'low_in_relevance',
#   'lead_profile': 'potential_lead',
#   'city': 'other_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'modified',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 739,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'olark_chat_conversation',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'yes',
#   'last_activity': 'email_bounced',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'low_in_relevance',
#   'lead_profile': 'other_leads',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'modified',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 837,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'olark_chat_conversation',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 17.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'lead_add_form',
#   'lead_source': 'reference',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'human_resource_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'working_professional',
#   'tags': 'closed_by_horizzon',
#   'lead_quality': 'high_in_relevance',
#   'lead_profile': 'potential_lead',
#   'city': 'other_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 1.0,
#   'total_time_spent_on_website': 938,
#   'page_views_per_visit': 1.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'online_search',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'busy',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 253,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'lead_add_form',
#   'lead_source': 'reference',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'it_projects_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'high_in_relevance',
#   'lead_profile': 'potential_lead',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'yes',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'student_of_someschool',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'already_a_student',
#   'lead_quality': 'worst',
#   'lead_profile': 'student_of_someschool',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 435,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 16.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'hospitality_management',
#   'how_did_you_hear_about_x_education': 'word_of_mouth',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'switched_off',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'other_metro_cities',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 262,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 13.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'banking,_investment_and_insurance',
#   'how_did_you_hear_about_x_education': 'multiple_sources',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'switched_off',
#   'lead_quality': 'not_sure',
#   'lead_profile': 'select',
#   'city': 'thane_&_outskirts',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 121,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 17.0},
#  {'lead_origin': 'api',
#   'lead_source': 'organic_search',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'south_africa',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 13.0,
#   'total_time_spent_on_website': 475,
#   'page_views_per_visit': 2.17,
#   'asymmetrique_activity_score': 15.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'lead_import',
#   'lead_source': 'facebook',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'e-commerce',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'graduation_in_progress',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '03.low',
#   'asymmetrique_profile_index': '03.low',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 11.0,
#   'asymmetrique_profile_score': 12.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'interested_in_other_courses',
#   'lead_quality': 'not_sure',
#   'lead_profile': 'other_leads',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'student',
#   'tags': 'lost_to_eins',
#   'lead_quality': 'worst',
#   'lead_profile': 'student_of_someschool',
#   'city': 'select',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 17.0,
#   'asymmetrique_profile_score': 14.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'operations_management',
#   'how_did_you_hear_about_x_education': 'select',
# ...
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'select',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 4.0,
#   'total_time_spent_on_website': 1761,
#   'page_views_per_visit': 4.0,
#   'asymmetrique_activity_score': 16.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'retail_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 9.0,
#   'total_time_spent_on_website': 354,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'api',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 167,
#   'page_views_per_visit': 1.5,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'lead_add_form',
#   'lead_source': 'reference',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'working_professional',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'potential_lead',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 15.0,
#   'asymmetrique_profile_score': 19.0},
#  {'lead_origin': 'api',
#   'lead_source': 'referral_sites',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'interested_in_other_courses',
#   'lead_quality': 'low_in_relevance',
#   'lead_profile': 'potential_lead',
#   'city': 'thane_&_outskirts',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 11.0,
#   'total_time_spent_on_website': 366,
#   'page_views_per_visit': 3.67,
#   'asymmetrique_activity_score': 15.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'api',
#   'lead_source': 'organic_search',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'ringing',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 6.0,
#   'total_time_spent_on_website': 1,
#   'page_views_per_visit': 6.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'yes',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'advertisements',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 9.0,
#   'total_time_spent_on_website': 1066,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 13.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'api',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '01.high',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 5.0,
#   'total_time_spent_on_website': 636,
#   'page_views_per_visit': 2.5,
#   'asymmetrique_activity_score': 16.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'page_visited_on_website',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'student_of_someschool',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'other_cities_of_maharashtra',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'page_visited_on_website',
#   'totalvisits': 11.0,
#   'total_time_spent_on_website': 116,
#   'page_views_per_visit': 3.67,
#   'asymmetrique_activity_score': 13.0,
#   'asymmetrique_profile_score': 17.0},
#  {'lead_origin': 'api',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'olark_chat_conversation',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'interested_in_other_courses',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'modified',
#   'totalvisits': 6.0,
#   'total_time_spent_on_website': 692,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 16.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'marketing_management',
#   'how_did_you_hear_about_x_education': 'online_search',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 3.0,
#   'total_time_spent_on_website': 201,
#   'page_views_per_visit': 3.0,
#   'asymmetrique_activity_score': 13.0,
#   'asymmetrique_profile_score': 18.0},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'ringing',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 4.0,
#   'total_time_spent_on_website': 373,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'finance_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'ringing',
#   'lead_quality': 'not_sure',
#   'lead_profile': 'select',
#   'city': 'other_cities_of_maharashtra',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'sms_sent',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 333,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'lead_add_form',
#   'lead_source': 'reference',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'banking,_investment_and_insurance',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'working_professional',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'potential_lead',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '01.high',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 3.445237833681204,
#   'total_time_spent_on_website': 1203,
#   'page_views_per_visit': 2.3628199494672084,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 19.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'ringing',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 15.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'api',
#   'lead_source': 'olark_chat',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 0.0,
#   'total_time_spent_on_website': 0,
#   'page_views_per_visit': 0.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'landing_page_submission',
#   'lead_source': 'direct_traffic',
#   'do_not_email': 'no',
#   'last_activity': 'page_visited_on_website',
#   'country': 'india',
#   'specialization': 'supply_chain_management',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'already_a_student',
#   'lead_quality': 'worst',
#   'lead_profile': 'student_of_someschool',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'yes',
#   'last_notable_activity': 'modified',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 737,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  {'lead_origin': 'api',
#   'lead_source': 'google',
#   'do_not_email': 'no',
#   'last_activity': 'email_opened',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'already_a_student',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'select',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'email_opened',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 94,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.0,
#   'asymmetrique_profile_score': 15.0},
#  {'lead_origin': 'api',
#   'lead_source': 'organic_search',
#   'do_not_email': 'yes',
#   'last_activity': 'sms_sent',
#   'country': 'india',
#   'specialization': 'select',
#   'how_did_you_hear_about_x_education': 'select',
#   'what_is_your_current_occupation': 'unemployed',
#   'tags': 'will_revert_after_reading_the_email',
#   'lead_quality': 'might_be',
#   'lead_profile': 'select',
#   'city': 'mumbai',
#   'asymmetrique_activity_index': '02.medium',
#   'asymmetrique_profile_index': '02.medium',
#   'a_free_copy_of_mastering_the_interview': 'no',
#   'last_notable_activity': 'modified',
#   'totalvisits': 2.0,
#   'total_time_spent_on_website': 342,
#   'page_views_per_visit': 2.0,
#   'asymmetrique_activity_score': 14.306252489048187,
#   'asymmetrique_profile_score': 16.344882516925527},
#  ...]

# %%
dv = DictVectorizer(sparse=False)
dv.fit(train_dic)
# Out:
# DictVectorizer(sparse=False)

# %%
X_train = dv.transform(train_dic)

# %% [markdown]
# ### Logistic Regression Model

# %% [markdown]
# * Training Logistic Regression

# %%
model = LogisticRegression(solver='liblinear',random_state=1)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=1, solver='liblinear')

# %% [markdown]
# * Cross Validation

# %%
val_dic = df_val[new_categorical+numerical].to_dict(orient='records')
X_val = dv.transform(val_dic)

# %%
y_pred = model.predict_proba(X_val)[:,1]
y_pred
# Out:
# array([3.02457766e-04, 9.38885449e-01, 9.41555341e-01, ...,
#        3.98445853e-01, 3.87249833e-01, 3.51191295e-03])

# %%
converted = y_pred>0.5

# %% [markdown]
# ### Evaluation Logistic Regression

# %% [markdown]
# * Accuracy

# %%
accuracy = (y_val==converted).mean()
print("accuracy: ", accuracy)
# Out:
# accuracy:  0.925

# %% [markdown]
# * Confusion Matrix

# %%
t = 0.5
predict_converted = (y_pred >= t)
predict_no_converted= (y_pred < t)

actual_converted = (y_val == 1)
actual_no_converted = (y_val == 0)

true_positive = (predict_converted & actual_converted).sum()
false_positive = (predict_converted & actual_no_converted).sum()
false_negative = (predict_no_converted & actual_converted).sum()
true_negative = (predict_no_converted & actual_no_converted).sum()

# %%
confusion_table = np.array(
[[true_negative, false_positive],
[false_negative, true_positive]])
confusion_table
# Out:
# array([[1410,   90],
#        [  93,  847]])

# %%
confusion_table / confusion_table.sum()*100
# Out:
# array([[57.78688525,  3.68852459],
#        [ 3.81147541, 34.71311475]])

# %% [markdown]
# * Precision

# %%
P = true_positive/(false_positive+true_positive)
P
# Out:
# 0.9039487726787621

# %% [markdown]
# * Recall

# %%
R =  true_positive/ (true_positive + false_negative)
R
# Out:
# 0.9010638297872341

# %% [markdown]
# * ROC

# %%
FPR = false_positive/(false_positive+true_negative)
print('False Positive Rate= ',FPR*100,'%')
# Out:
# False Positive Rate=  6.0 %
